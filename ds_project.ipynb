# %% [markdown]
# <a href="https://colab.research.google.com/github/Aayushi3j3j/Color-Site/blob/main/ds_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Marketing Analytics and EDA**
#
# 1) Exploratory Data Analysis : Exploratory data analysis (EDA) is used to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods.
#
# It helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.
#
# 2) Statistical Analysis : Statistical analysis means investigating trends, patterns, and relationships using quantitative data. It is an important research tool used by scientists, governments, businesses, and other organizations.
#
# 3) Data Visualization :
# Data visualization is useful for data cleaning, exploring data structure, detecting outliers and unusual groups, identifying trends and clusters, spotting local patterns, evaluating modeling output, and presenting results.
#
#  Task to check :-
#  * Are there any null values or outliers?
#
# *    How will you wrangle/handle them?
# *   Are there any variables that warrant transformations?
#
# *   Are there any useful variables that you can engineer with the given data?
# *   Do you notice any patterns or anomalies in the data?
#
# *   Can you plot them?

# %%
import pandas as pd  #Importing pandas to read CSV File
df = pd.read_csv('/content/marketing_data.csv')  # Different  Location File
print(df)
# Out:
#          ID  Year_Birth   Education  ... Response Complain  Country
# 0      1826        1970  Graduation  ...        1        0       SP
# 1         1        1961  Graduation  ...        1        0       CA
# 2     10476        1958  Graduation  ...        0        0       US
# 3      1386        1967  Graduation  ...        0        0      AUS
# 4      5371        1989  Graduation  ...        1        0       SP
# ...     ...         ...         ...  ...      ...      ...      ...
# 2235  10142        1976         PhD  ...        0        0       US
# 2236   5263        1977    2n Cycle  ...        0        0       SP
# 2237     22        1976  Graduation  ...        0        0       SP
# 2238    528        1978  Graduation  ...        0        0      IND
# 2239   4070        1969         PhD  ...        1        0       CA
#
# [2240 rows x 28 columns]

# %%
size = df.size  #Calculating the Size of Dataset.
print(size)
# Out:
# 62720

# %%
shape = df.shape  #Calculating the Number of Rows and Columns for finding the Dimensions of Dataset.
print(shape)
# Out:
# (2240, 28)

# %%
for col in df.columns:  #For Getting Output as Column Names of Dataset.
    print(col)
# Out:
# ID
# Year_Birth
# Education
# Marital_Status
#  Income
# Kidhome
# Teenhome
# Dt_Customer
# Recency
# MntWines
# MntFruits
# MntMeatProducts
# MntFishProducts
# MntSweetProducts
# MntGoldProds
# NumDealsPurchases
# NumWebPurchases
# NumCatalogPurchases
# NumStorePurchases
# NumWebVisitsMonth
# AcceptedCmp3
# AcceptedCmp4
# AcceptedCmp5
# AcceptedCmp1
# AcceptedCmp2
# Response
# Complain
# Country

# %%
print(df.NumWebPurchases)  #Printing the column used to be work
# Out:
# 0       4
# 1       7
# 2       3
# 3       1
# 4       3
#        ..
# 2235    5
# 2236    1
# 2237    6
# 2238    5
# 2239    8
# Name: NumWebPurchases, Length: 2240, dtype: int64

# %%
dataframe_ndim = df.ndim  #Used to get Dimension of Dataset.
print(dataframe_ndim)
# Out:
# 2

# %%
series_ndim = df["NumWebPurchases"].ndim  # find the dimension of the given Series object.
print(series_ndim)
# Out:
# 1

# %%
df1 = df.NumWebPurchases  #Stored the column  in var to work separately.
print(df1)
# Out:
# 0       4
# 1       7
# 2       3
# 3       1
# 4       3
#        ..
# 2235    5
# 2236    1
# 2237    6
# 2238    5
# 2239    8
# Name: NumWebPurchases, Length: 2240, dtype: int64

# %%
df.describe()  #To find Mean,Standard Deviation , Minimum Value & Maximum Value.
# Out:
#                  ID   Year_Birth  ...     Response     Complain
# count   2240.000000  2240.000000  ...  2240.000000  2240.000000
# mean    5592.159821  1968.805804  ...     0.149107     0.009375
# std     3246.662198    11.984069  ...     0.356274     0.096391
# min        0.000000  1893.000000  ...     0.000000     0.000000
# 25%     2828.250000  1959.000000  ...     0.000000     0.000000
# 50%     5458.500000  1970.000000  ...     0.000000     0.000000
# 75%     8427.750000  1977.000000  ...     0.000000     0.000000
# max    11191.000000  1996.000000  ...     1.000000     1.000000
#
# [8 rows x 23 columns]

# %%
unique_df = pd.unique(df.NumWebPurchases) #To Find Unique Value of the coulmn
print(unique_df)
# Out:
# [ 4  7  3  1 10  2  6  5 25  8  9  0 11 27 23]

# %%
df.isnull().sum() #To Find Total Number of Null Values.
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
clear_df = df.dropna()  # To clear the Null Values of Dataset
print(clear_df.to_string())
# Out:
#          ID  Year_Birth   Education Marital_Status       Income   Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain Country
# 0      1826        1970  Graduation       Divorced   $84,835.00         0         0     6/16/14        0       189        104              379              111               189           218                  1                4                    4                  6                  1             0             0             0             0             0         1         0      SP
# ...

# %%
import matplotlib.pyplot as plt  #Importing libraries for Data Visualization.
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df.corr() #finding correlation between the coumns of dataset.
# Out:
#                            ID  Year_Birth  ...  Response  Complain
# ID                   1.000000    0.000028  ... -0.021968  0.033883
# Year_Birth           0.000028    1.000000  ...  0.021325 -0.030128
# Kidhome              0.002406    0.230176  ... -0.080008  0.040207
# Teenhome            -0.002580   -0.352111  ... -0.154446  0.003138
# Recency             -0.046524   -0.019871  ... -0.198437  0.013231
# MntWines            -0.022878   -0.157773  ...  0.247254 -0.039007
# MntFruits            0.004600   -0.017917  ...  0.125289 -0.005166
# MntMeatProducts     -0.004437   -0.030872  ...  0.236335 -0.023483
# MntFishProducts     -0.024475   -0.041625  ...  0.111331 -0.020953
# MntSweetProducts    -0.007642   -0.018133  ...  0.117372 -0.022485
# MntGoldProds        -0.013438   -0.061818  ...  0.139850 -0.030861
# NumDealsPurchases   -0.037166   -0.060846  ...  0.002238  0.000420
# NumWebPurchases     -0.018924   -0.145040  ...  0.148730 -0.016310
# ...

# %%
sns.heatmap(df.corr())  #Heatmap of correlated values.

# %%
sns.relplot(x ="Year_Birth", y ="NumWebPurchases", #Relationship Plot
			data = df);

# %%
df.plot.box()  #Box Plot
plt.boxplot(df['Year_Birth'])
plt.show()

# %%
df.hist() #Histogram
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdac8c65f90>,
# ...
#       dtype=object)

# %%
df.plot()  #Line Plot

# %%
df["NumWebPurchases"].plot(kind = 'hist') #Histogram

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=[ "NumWebPurchases","Year_Birth"])  #Area Plot
df.plot.area();

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["NumWebPurchases", "Year_Birth"])  #HexogonalBin Plot

df["Year_Birth"] = df["Year_Birth"] + np.arange(1000)

df.plot.hexbin(x="NumWebPurchases", y="Year_Birth", gridsize=25,cmap=plt.cm.cool);

# %%
heatmap1_data = pd.pivot_table(df, index=['Year_Birth'], values='NumWebPurchases')

# %%
sns.heatmap(heatmap1_data, cmap="YlGnBu") #HeatMap Plot
